# %% [markdown]
# <a href="https://colab.research.google.com/github/KimYuri94/DigitalImageProcessing/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5

# %%
# !pip install -r requirements.txt

# %%
# !unzip -q /content/safety-helmet-yolov5.v4-500annotations.yolov5pytorch.zip

# %%
# !python train.py --img 416 --batch 8 --epochs 149 --data coco128.yaml --weights yolov5s.pt --nosave --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=149, batch_size=8, imgsz=416, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CPU
#
# ...

# %%
# !python detect.py --source /content/yolov5/test/images --weights /content/yolov5/runs/train/exp/weights/last.pt --img 416 --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=/content/yolov5/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/51 /content/yolov5/test/images/hard_hat_workers104_png.rf.41f01d88aff6b406d0ff8419155f83a8.jpg: 416x416 5 unsafes, Done. (0.187s)
# image 2/51 /content/yolov5/test/images/hard_hat_workers27_png.rf.4006e21b0a13cf4d031cb502352e21dc.jpg: 416x416 3 safes, Done. (0.170s)
# ...
